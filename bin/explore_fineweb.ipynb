# %%
from datasets import Dataset

ds = Dataset.from_file("../data/fineweb-edu/data-00000-of-00099.arrow")

# Convert to pandas dataframe
df = ds.to_pandas()

print(df)
print(df.head(10))
print(df.info())
print(df.describe())
# Out:
#                                                     text  \
# 0      The Independent Jane\nFor all the love, romanc...
# 1      Taking Play Seriously\nBy ROBIN MARANTZ HENIG\...
# 2      How do you get HIV?\nHIV can be passed on when...
# 3      CTComms sends on average 2 million emails mont...
# 4      Hold the salt: UCLA engineers develop revoluti...
# ...                                                  ...
# 97693  Learn something new every day More Info... by ...
# 97694  Lifting weights before puberty makes children ...
# 97695  Researchers there, including scientists at Bri...
# 97696  Classes for performers, composers, teachers, o...
# 97697  Noun: floor flor\nVerb: floor flor\n- The insi...
#
#                                                     id             dump  \
# 0      <urn:uuid:0d8a309d-25c5-405d-a08a-c11239f0d717>  CC-MAIN-2013-20
# 1      <urn:uuid:316c7af5-14e1-4d0b-9576-753e17ef2cc5>  CC-MAIN-2013-20
# 2      <urn:uuid:a3e140cd-7f25-48c9-a2f0-a7d0b1954e0d>  CC-MAIN-2013-20
# 3      <urn:uuid:c337bcd8-6aa1-4f2d-8c48-b916442ebbee>  CC-MAIN-2013-20
# 4      <urn:uuid:c0b175bb-65fb-420e-a881-a80b91d00ecd>  CC-MAIN-2013-20
# ...                                                ...              ...
# 97693  <urn:uuid:535f115e-2f0c-4e89-8183-d537dd3b2f7b>  CC-MAIN-2013-20
# 97694  <urn:uuid:f62e3dbb-e965-4b9f-bf1d-e1b8990c1036>  CC-MAIN-2013-20
# 97695  <urn:uuid:debbd4d7-74e6-42a1-99de-0c6a8549bee5>  CC-MAIN-2013-20
# 97696  <urn:uuid:b978a63f-5e40-4a52-a48a-ef1ea6b28198>  CC-MAIN-2013-20
# 97697  <urn:uuid:4e609f5d-a004-438c-95da-eda1cddb26e6>  CC-MAIN-2013-20
#
#                                                      url  \
# 0          http://austenauthors.net/the-independent-jane
# 1      http://query.nytimes.com/gst/fullpage.html?res...
# 2      http://www.childline.org.uk/Explore/SexRelatio...
# 3      http://www.ctt.org/resource_centre/getting_sta...
# 4      http://www.environment.ucla.edu/water/news/art...
# ...                                                  ...
# 97693  http://www.wisegeek.com/what-is-cyclamen-heder...
# 97694  http://drmirkin.blogspot.com/2010/12/children-...
# 97695  http://www.earthweek.com/2012/ew121207/ew12120...
# 97696  http://www.edcc.edu/music/_programs/MusicTheor...
# 97697              http://www.wordwebonline.com/en/FLOOR
#
#                                                file_path language  \
# 0      s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en
# 1      s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en
# 2      s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en
# 3      s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en
# 4      s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en
# ...                                                  ...      ...
# 97693  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en
# 97694  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en
# 97695  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en
# 97696  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en
# 97697  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en
#
#        language_score  token_count     score  int_score
# 0            0.974320          845  2.750000          3
# 1            0.961459         1055  2.562500          3
# 2            0.966757          136  3.125000          3
# 3            0.910602         3479  3.234375          3
# 4            0.924981         1115  2.812500          3
# ...               ...          ...       ...        ...
# 97693        0.925916          632  3.234375          3
# 97694        0.977682          819  3.656250          4
# 97695        0.910658          178  3.296875          3
# 97696        0.916723          282  3.062500          3
# 97697        0.932648          432  2.578125          3
#
# [97698 rows x 10 columns]
#                                                 text  \
# 0  The Independent Jane\nFor all the love, romanc...
# 1  Taking Play Seriously\nBy ROBIN MARANTZ HENIG\...
# 2  How do you get HIV?\nHIV can be passed on when...
# 3  CTComms sends on average 2 million emails mont...
# 4  Hold the salt: UCLA engineers develop revoluti...
# 5  Not Just for Kids\nThe Hunt for Falling Leaves...
# 6  The Solar and Heliospheric Observatory (SOHO) ...
# 7  Bolivia: Coca-chewing protest outside US embas...
# 8  Breaking the COX code\nUsing the team approach...
# 9  Discover the cosmos! Each day a different imag...
#
#                                                 id             dump  \
# 0  <urn:uuid:0d8a309d-25c5-405d-a08a-c11239f0d717>  CC-MAIN-2013-20
# 1  <urn:uuid:316c7af5-14e1-4d0b-9576-753e17ef2cc5>  CC-MAIN-2013-20
# 2  <urn:uuid:a3e140cd-7f25-48c9-a2f0-a7d0b1954e0d>  CC-MAIN-2013-20
# 3  <urn:uuid:c337bcd8-6aa1-4f2d-8c48-b916442ebbee>  CC-MAIN-2013-20
# 4  <urn:uuid:c0b175bb-65fb-420e-a881-a80b91d00ecd>  CC-MAIN-2013-20
# 5  <urn:uuid:373cc951-d17e-4d57-b0f5-122effe3a054>  CC-MAIN-2013-20
# 6  <urn:uuid:78cbe1bd-1849-4138-b59a-5521e93122a3>  CC-MAIN-2013-20
# 7  <urn:uuid:a63f6870-f496-4355-adfd-f3296c1577e5>  CC-MAIN-2013-20
# 8  <urn:uuid:0428aaca-1b84-4407-9b6f-93b230a692b3>  CC-MAIN-2013-20
# 9  <urn:uuid:6665d40b-fee1-4353-8a03-3268af4a76bb>  CC-MAIN-2013-20
#
#                                                  url  \
# 0      http://austenauthors.net/the-independent-jane
# 1  http://query.nytimes.com/gst/fullpage.html?res...
# 2  http://www.childline.org.uk/Explore/SexRelatio...
# 3  http://www.ctt.org/resource_centre/getting_sta...
# 4  http://www.environment.ucla.edu/water/news/art...
# 5  http://bayweekly.com/old-site/year99/issue7_40...
# 6                      http://phys.org/news4969.html
# 7  http://www.bbc.co.uk/news/world-latin-america-...
# 8  http://www.mc.vanderbilt.edu/lens/article/?id=...
# 9            http://apod.nasa.gov/apod/ap120623.html
#
#                                            file_path language  language_score  \
# 0  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en        0.974320
# 1  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en        0.961459
# 2  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en        0.966757
# 3  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en        0.910602
# 4  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en        0.924981
# 5  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en        0.936883
# 6  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en        0.943417
# 7  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en        0.966039
# 8  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en        0.943982
# 9  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en        0.899348
#
#    token_count     score  int_score
# 0          845  2.750000          3
# 1         1055  2.562500          3
# 2          136  3.125000          3
# 3         3479  3.234375          3
# 4         1115  2.812500          3
# 5          869  2.562500          3
# 6          663  4.000000          4
# 7          484  2.703125          3
# 8          607  2.937500          3
# 9          195  3.203125          3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97698 entries, 0 to 97697
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   text            97698 non-null  object
#  1   id              97698 non-null  object
#  2   dump            97698 non-null  object
#  3   url             97698 non-null  object
#  4   file_path       97698 non-null  object
#  5   language        97698 non-null  object
#  6   language_score  97698 non-null  float64
#  7   token_count     97698 non-null  int64
#  8   score           97698 non-null  float64
#  9   int_score       97698 non-null  int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 7.5+ MB
# None
#        language_score    token_count         score     int_score
# count    97698.000000   97698.000000  97698.000000  97698.000000
# mean         0.936101    1048.173780      3.007571      3.134343
# std          0.041587    1855.040545      0.397396      0.343146
# min          0.650017      58.000000      2.515625      3.000000
# 25%          0.924115     349.000000      2.687500      3.000000
# 50%          0.945944     631.000000      2.906250      3.000000
# 75%          0.961315    1111.000000      3.250000      3.000000
# max          0.997417  104023.000000      5.062500      5.000000

# %%
df.columns
# Out:
# Index(['text', 'id', 'dump', 'url', 'file_path', 'language', 'language_score',
#        'token_count', 'score', 'int_score'],
#       dtype='object')

# %%
df.head(1)
# Out:
#                                                 text  \
# 0  The Independent Jane\nFor all the love, romanc...
#
#                                                 id             dump  \
# 0  <urn:uuid:0d8a309d-25c5-405d-a08a-c11239f0d717>  CC-MAIN-2013-20
#
#                                              url  \
# 0  http://austenauthors.net/the-independent-jane
#
#                                            file_path language  language_score  \
# 0  s3://commoncrawl/crawl-data/CC-MAIN-2013-20/se...       en         0.97432
#
#    token_count  score  int_score
# 0          845   2.75          3

# %%
from transformers import GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Get first text
text = df['text'].iloc[0]

# Count tokens
tokens = tokenizer.tokenize(text)
print(f"Actual token count: {len(tokens)}")
print(f"Dataset token_count: {df['token_count'].iloc[0]}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Actual token count: 845
# Dataset token_count: 845
